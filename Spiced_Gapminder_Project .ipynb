# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
pip install imageio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
gap=pd.read_excel("gapminder_lifeexpectancy.xlsx")

# %%
con=pd.read_csv("continents.csv", sep=";")

# %%
fer=pd.read_csv("gapminder_total_fertility.csv", index_col=0)

# %%
fert=fer.copy()
cont=con.copy()
life=gap.copy()

# %%
life.shape
# Out:
# (260, 218)

# %%
fert.shape
# Out:
# (260, 216)

# %%
life.columns
# Out:
# Index(['Life expectancy',            1800.0,            1801.0,
#                   1802.0,            1803.0,            1804.0,
#                   1805.0,            1806.0,            1807.0,
#                   1808.0,
#        ...
#                   2007.0,            2008.0,            2009.0,
#                   2010.0,            2011.0,            2012.0,
#                   2013.0,            2014.0,            2015.0,
#                   2016.0],
#       dtype='object', length=218)

# %%
fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
fert.columns=fert.columns.astype(int)

# %%
fert.index
# Out:
# Life expectancy     0
# 1800.0             59
# 1801.0             59
# 1802.0             59
# 1803.0             59
#                    ..
# 2012.0             52
# 2013.0             52
# 2014.0             52
# 2015.0             52
# 2016.0             52
# Length: 218, dtype: int64

# %%
gap1
# Out:
#            Life expectancy  1800.0  1801.0  1802.0  1803.0  1804.0  1805.0  \
# 0                 Abkhazia     NaN     NaN     NaN     NaN     NaN     NaN
# 1              Afghanistan   28.21   28.20   28.19   28.18   28.17   28.16
# 2    Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN
# 3                  Albania   35.40   35.40   35.40   35.40   35.40   35.40
# 4                  Algeria   28.82   28.82   28.82   28.82   28.82   28.82
# ..                     ...     ...     ...     ...     ...     ...     ...
# 255             Yugoslavia     NaN     NaN     NaN     NaN     NaN     NaN
# 256                 Zambia   32.60   32.60   32.60   32.60   32.60   32.60
# 257               Zimbabwe   33.70   33.70   33.70   33.70   33.70   33.70
# 258                  Åland     NaN     NaN     NaN     NaN     NaN     NaN
# 259            South Sudan   26.67   26.67   26.67   26.67   26.67   26.67
#
# ...

# %%
gap1=gap1.rename(columns={"Life expectancy":"country"})

# %%
gap1.head()
# Out:
#                  country  1800.0  1801.0  1802.0  1803.0  1804.0  1805.0  \
# 0               Abkhazia     NaN     NaN     NaN     NaN     NaN     NaN
# 1            Afghanistan   28.21   28.20   28.19   28.18   28.17   28.16
# 2  Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN
# 3                Albania   35.40   35.40   35.40   35.40   35.40   35.40
# 4                Algeria   28.82   28.82   28.82   28.82   28.82   28.82
#
#    1806.0  1807.0  1808.0  ...  2007.0  2008.0  2009.0  2010.0  2011.0  \
# 0     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1   28.15   28.14   28.13  ...    52.4    52.8    53.3    53.6    54.0
# 2     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 3   35.40   35.40   35.40  ...    76.6    76.8    77.0    77.2    77.4
# 4   28.82   28.82   28.82  ...    75.3    75.5    75.7    76.0    76.1
#
#    2012.0  2013.0  2014.0  2015.0  2016.0
# 0     NaN     NaN     NaN     NaN     NaN
# ...

# %%
df=pd.merge(con1, gap1, how="inner", on="country")

# %%
df
# Out:
#          continent    country  1800.0  1801.0  1802.0  1803.0  1804.0  1805.0  \
# 0           Africa    Algeria   28.82   28.82   28.82   28.82   28.82   28.82
# 1           Africa     Angola   26.98   26.98   26.98   26.98   26.98   26.98
# 2           Africa      Benin   31.00   31.00   31.00   31.00   31.00   31.00
# 3           Africa   Botswana   33.60   33.60   33.60   33.60   33.60   33.60
# 4           Africa    Burundi   31.50   31.50   31.50   31.50   31.50   31.50
# ..             ...        ...     ...     ...     ...     ...     ...     ...
# 171  South America   Paraguay   35.50   35.50   35.50   35.50   35.50   35.50
# 172  South America       Peru   35.70   35.70   35.70   35.70   35.70   35.70
# 173  South America   Suriname   32.90   32.90   32.90   32.90   32.90   32.90
# 174  South America    Uruguay   32.90   32.90   32.90   32.90   32.90   32.90
# 175  South America  Venezuela   32.20   32.20   32.20   32.20   32.20   32.20
#
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#          continent    country  1800.0  1801.0  1802.0  1803.0  1804.0  1805.0  \
# 0           Africa    Algeria   28.82   28.82   28.82   28.82   28.82   28.82
# 1           Africa     Angola   26.98   26.98   26.98   26.98   26.98   26.98
# 2           Africa      Benin   31.00   31.00   31.00   31.00   31.00   31.00
# 3           Africa   Botswana   33.60   33.60   33.60   33.60   33.60   33.60
# 4           Africa    Burundi   31.50   31.50   31.50   31.50   31.50   31.50
# ..             ...        ...     ...     ...     ...     ...     ...     ...
# 171  South America   Paraguay   35.50   35.50   35.50   35.50   35.50   35.50
# 172  South America       Peru   35.70   35.70   35.70   35.70   35.70   35.70
# 173  South America   Suriname   32.90   32.90   32.90   32.90   32.90   32.90
# 174  South America    Uruguay   32.90   32.90   32.90   32.90   32.90   32.90
# 175  South America  Venezuela   32.20   32.20   32.20   32.20   32.20   32.20
#
# ...

# %%
df2=df.melt(id_vars=["country", "continent"], var_name="year", value_name="life_expectancy")
df2
# Out:
#          country      continent    year  life_expectancy
# 0        Algeria         Africa  1800.0            28.82
# 1         Angola         Africa  1800.0            26.98
# 2          Benin         Africa  1800.0            31.00
# 3       Botswana         Africa  1800.0            33.60
# 4        Burundi         Africa  1800.0            31.50
# ...          ...            ...     ...              ...
# 36234   Paraguay  South America  2016.0            74.50
# 36235       Peru  South America  2016.0            79.70
# 36236   Suriname  South America  2016.0            72.20
# 36237    Uruguay  South America  2016.0            77.00
# 36238  Venezuela  South America  2016.0            74.80
#
# [36239 rows x 4 columns]

# %%
sns.boxplot(data=df2, x="life_expectancy", y="continent")
# Out:
# <AxesSubplot:xlabel='life_expectancy', ylabel='continent'>

# %%
sns.lineplot(data=df2, x="year", y="life_expectancy", hue="continent")
# Out:
# <AxesSubplot:xlabel='year', ylabel='life_expectancy'>

# %%
df2["year"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.figure(figsize=(15,7))
plt.scatter(data=df2,x="year", y="life_expectancy")
plt.title("Life Expectancy Chart")
plt.show()

# %%
sns.swarmplot(df2["year"], df2["life_expectancy"]);

# %%
sns.jointplot(df2["year"], df2["life_expectancy"], kind="kde");

# %%
df3=pd.merge(con1, gap1, how="inner", on="country")
